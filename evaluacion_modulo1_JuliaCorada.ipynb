# %%
class TiendaOnline:
    def __init__(self):
        self.inventario = [] #lista vacia donde guardar los productos
        self.ventas_totales = 0 #el total de las ventas acumuladas
